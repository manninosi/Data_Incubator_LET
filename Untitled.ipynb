# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


file_01= "county_lex_2020-01-20.csv.gz"
file_02= "county_lex_2020-02-01.csv.gz"
file_03= "county_lex_2020-03-01.csv.gz"
file_04= "county_lex_2020-04-14.csv.gz"

df_01 	= pd.read_csv(file_01, compression='gzip', header=0)
df_02 	= pd.read_csv(file_02, compression='gzip', header=0)
df_03 	= pd.read_csv(file_03, compression='gzip', header=0)
df_04 	= pd.read_csv(file_04, compression='gzip', header=0)

# %%
#Selecting mississppi counties 
#Jan
df_01_MS = pd.concat([df_01.loc[:,"COUNTY_PRE"],df_01.loc[:,"28001":"28163"]], axis=1)
df_01_MS = df_01_MS[df_01_MS['COUNTY_PRE']>=28001]
df_01_MS = df_01_MS[df_01_MS['COUNTY_PRE']<=28163]
#Feb
df_02_MS = pd.concat([df_02.loc[:,"COUNTY_PRE"],df_02.loc[:,"28001":"28163"]], axis=1)
df_02_MS = df_02_MS[df_02_MS['COUNTY_PRE']>=28001]
df_02_MS = df_02_MS[df_02_MS['COUNTY_PRE']<=28163]
#Mar
df_03_MS = pd.concat([df_03.loc[:,"COUNTY_PRE"],df_03.loc[:,"28001":"28163"]], axis=1)
df_03_MS = df_03_MS[df_03_MS['COUNTY_PRE']>=28001]
df_03_MS = df_03_MS[df_03_MS['COUNTY_PRE']<=28163]
#Apr
df_04_MS = pd.concat([df_04.loc[:,"COUNTY_PRE"],df_04.loc[:,"28001":"28163"]], axis=1)
df_04_MS = df_04_MS[df_04_MS['COUNTY_PRE']>=28001]
df_04_MS = df_04_MS[df_04_MS['COUNTY_PRE']<=28163]
frame_MS = {'Jan': df_01_MS.iloc[:,1:].mean(), 'Feb':df_02_MS.iloc[:,1:].mean(), 'Mar':df_03_MS.iloc[:,1:].mean(), 'Apr':df_04_MS.iloc[:,1:].mean()}
pd.DataFrame(frame_MS)
# Out:
#             Jan       Feb       Mar       Apr
# 28001  0.031046  0.030700  0.031761  0.025082
# 28003  0.046557  0.046428  0.048674  0.038696
# 28013  0.065445  0.063710  0.067622  0.052909
# 28017  0.064343  0.064258  0.068199  0.054862
# 28023  0.060054  0.060269  0.064514  0.048100
# 28027  0.042685  0.038534  0.041037  0.034956
# 28029  0.058316  0.059765  0.061428  0.048773
# 28031  0.075853  0.072161  0.079266  0.064823
# 28033  0.030426  0.030284  0.032571  0.028965
# 28035  0.059758  0.057544  0.063808  0.048592
# 28039  0.046367  0.045031  0.047602  0.035338
# 28043  0.050717  0.051899  0.055427  0.040424
# 28045  0.042849  0.041746  0.044074  0.038443
# 28047  0.036965  0.037207  0.039379  0.032746
# 28049  0.052081  0.051184  0.053440  0.043013
# 28057  0.053876  0.052629  0.057124  0.049527
# 28059  0.038308  0.037924  0.039819  0.032343
# 28061  0.073069  0.071350  0.076253  0.060126
# 28067  0.061725  0.060776  0.064501  0.048467
# 28071  0.049481  0.047759  0.051669  0.040972
# 28073  0.059297  0.058473  0.063015  0.046828
# 28075  0.043555  0.041788  0.043606  0.034012
# 28079  0.064011  0.064360  0.068842  0.053046
# 28081  0.054097  0.054688  0.056565  0.045884
# 28083  0.050179  0.047324  0.052480  0.036923
# 28085  0.055591  0.054933  0.058970  0.040721
# 28087  0.041252  0.040075  0.042777  0.031720
# 28089  0.057852  0.057901  0.060738  0.044363
# 28093  0.044967  0.044701  0.045428  0.041872
# 28095  0.056695  0.055703  0.058521  0.045835
# 28099  0.060137  0.060249  0.064083  0.046161
# 28101  0.065013  0.064140  0.070460  0.055320
# 28105  0.046196  0.049041  0.050684  0.036244
# 28107  0.053149  0.051929  0.056067  0.043723
# 28109  0.042070  0.040569  0.043743  0.033667
# 28113  0.041892  0.040401  0.044240  0.033599
# 28115  0.065210  0.064838  0.069098  0.055428
# 28117  0.061299  0.060013  0.064802  0.052124
# 28121  0.058566  0.058324  0.062201  0.046191
# 28123  0.067735  0.066548  0.069706  0.056075
# 28127  0.069182  0.071033  0.075197  0.056119
# 28129  0.085240  0.083986  0.090179  0.067672
# 28131  0.060435  0.059073  0.065380  0.049637
# 28133  0.052696  0.049072  0.056847  0.040503
# 28137  0.049855  0.049305  0.052114  0.044368
# 28139  0.058612  0.057937  0.061662  0.047939
# 28141  0.054837  0.052285  0.056661  0.044389
# 28145  0.060743  0.061044  0.065559  0.054205
# 28149  0.041893  0.041467  0.044062  0.032199
# 28151  0.040225  0.038903  0.043857  0.031302
# 28153  0.053967  0.051854  0.058755  0.041630
# 28159  0.060673  0.059284  0.064088  0.043632
# 28163  0.060745  0.055786  0.063342  0.045335

# %%
#Selecting Idaho counties 
#Jan
df_01_MS = pd.concat([df_01.loc[:,"COUNTY_PRE"],df_01.loc[:,"28001":"28163"]], axis=1)
df_01_MS = df_01_MS[df_01_MS['COUNTY_PRE']>=28001]
df_01_MS = df_01_MS[df_01_MS['COUNTY_PRE']<=28163]
#Feb
df_02_MS = pd.concat([df_02.loc[:,"COUNTY_PRE"],df_02.loc[:,"28001":"28163"]], axis=1)
df_02_MS = df_02_MS[df_02_MS['COUNTY_PRE']>=28001]
df_02_MS = df_02_MS[df_02_MS['COUNTY_PRE']<=28163]
#Mar
df_03_MS = pd.concat([df_03.loc[:,"COUNTY_PRE"],df_03.loc[:,"28001":"28163"]], axis=1)
df_03_MS = df_03_MS[df_03_MS['COUNTY_PRE']>=28001]
df_03_MS = df_03_MS[df_03_MS['COUNTY_PRE']<=28163]
#Apr
df_04_MS = pd.concat([df_04.loc[:,"COUNTY_PRE"],df_04.loc[:,"28001":"28163"]], axis=1)
df_04_MS = df_04_MS[df_04_MS['COUNTY_PRE']>=28001]
df_04_MS = df_04_MS[df_04_MS['COUNTY_PRE']<=28163]
frame_MS = {'Jan': df_01_MS.iloc[:,1:].mean(), 'Feb':df_02_MS.iloc[:,1:].mean(), 'Mar':df_03_MS.iloc[:,1:].mean(), 'Apr':df_04_MS.iloc[:,1:].mean()}
pd.DataFrame(frame_MS)
